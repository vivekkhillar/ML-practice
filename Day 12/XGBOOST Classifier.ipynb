# %% [markdown]
# #### XG Classifier

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('bank-additional-full.csv', sep=";")
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
df.columns[df.dtypes == 'object']
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
df=pd.get_dummies(df,df.columns[df.dtypes == 'object'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 65 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            41188 non-null  int64
#  1   duration                       41188 non-null  int64
#  2   campaign                       41188 non-null  int64
#  3   pdays                          41188 non-null  int64
#  4   previous                       41188 non-null  int64
#  5   emp.var.rate                   41188 non-null  float64
#  6   cons.price.idx                 41188 non-null  float64
#  7   cons.conf.idx                  41188 non-null  float64
#  8   euribor3m                      41188 non-null  float64
#  9   nr.employed                    41188 non-null  float64
#  10  job_admin.                     41188 non-null  bool
#  11  job_blue-collar                41188 non-null  bool
#  12  job_entrepreneur               41188 non-null  bool
#  13  job_housemaid                  41188 non-null  bool
#  14  job_management                 41188 non-null  bool
#  15  job_retired                    41188 non-null  bool
#  16  job_self-employed              41188 non-null  bool
#  17  job_services                   41188 non-null  bool
#  18  job_student                    41188 non-null  bool
#  19  job_technician                 41188 non-null  bool
#  20  job_unemployed                 41188 non-null  bool
#  21  job_unknown                    41188 non-null  bool
#  22  marital_divorced               41188 non-null  bool
#  23  marital_married                41188 non-null  bool
#  24  marital_single                 41188 non-null  bool
#  25  marital_unknown                41188 non-null  bool
#  26  education_basic.4y             41188 non-null  bool
#  27  education_basic.6y             41188 non-null  bool
#  28  education_basic.9y             41188 non-null  bool
#  29  education_high.school          41188 non-null  bool
#  30  education_illiterate           41188 non-null  bool
#  31  education_professional.course  41188 non-null  bool
#  32  education_university.degree    41188 non-null  bool
#  33  education_unknown              41188 non-null  bool
#  34  default_no                     41188 non-null  bool
#  35  default_unknown                41188 non-null  bool
#  36  default_yes                    41188 non-null  bool
#  37  housing_no                     41188 non-null  bool
#  38  housing_unknown                41188 non-null  bool
#  39  housing_yes                    41188 non-null  bool
#  40  loan_no                        41188 non-null  bool
#  41  loan_unknown                   41188 non-null  bool
#  42  loan_yes                       41188 non-null  bool
#  43  contact_cellular               41188 non-null  bool
#  44  contact_telephone              41188 non-null  bool
#  45  month_apr                      41188 non-null  bool
#  46  month_aug                      41188 non-null  bool
#  47  month_dec                      41188 non-null  bool
#  48  month_jul                      41188 non-null  bool
#  49  month_jun                      41188 non-null  bool
#  50  month_mar                      41188 non-null  bool
#  51  month_may                      41188 non-null  bool
#  52  month_nov                      41188 non-null  bool
#  53  month_oct                      41188 non-null  bool
#  54  month_sep                      41188 non-null  bool
#  55  day_of_week_fri                41188 non-null  bool
#  56  day_of_week_mon                41188 non-null  bool
#  57  day_of_week_thu                41188 non-null  bool
#  58  day_of_week_tue                41188 non-null  bool
#  59  day_of_week_wed                41188 non-null  bool
#  60  poutcome_failure               41188 non-null  bool
#  61  poutcome_nonexistent           41188 non-null  bool
#  62  poutcome_success               41188 non-null  bool
#  63  y_no                           41188 non-null  bool
#  64  y_yes                          41188 non-null  bool
# dtypes: bool(55), float64(5), int64(5)
# memory usage: 5.3 MB

# %%
x = df.iloc[:,:-1]
x
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
#        cons.conf.idx  euribor3m  nr.employed  ...  month_sep  day_of_week_fri  \
# 0              -36.4      4.857       5191.0  ...      False            False
# 1              -36.4      4.857       5191.0  ...      False            False
# 2              -36.4      4.857       5191.0  ...      False            False
# 3              -36.4      4.857       5191.0  ...      False            False
# 4              -36.4      4.857       5191.0  ...      False            False
# ...              ...        ...          ...  ...        ...              ...
# 41183          -50.8      1.028       4963.6  ...      False             True
# 41184          -50.8      1.028       4963.6  ...      False             True
# 41185          -50.8      1.028       4963.6  ...      False             True
# 41186          -50.8      1.028       4963.6  ...      False             True
# 41187          -50.8      1.028       4963.6  ...      False             True
#
#        day_of_week_mon  day_of_week_thu  day_of_week_tue  day_of_week_wed  \
# 0                 True            False            False            False
# 1                 True            False            False            False
# 2                 True            False            False            False
# 3                 True            False            False            False
# 4                 True            False            False            False
# ...                ...              ...              ...              ...
# 41183            False            False            False            False
# 41184            False            False            False            False
# 41185            False            False            False            False
# 41186            False            False            False            False
# 41187            False            False            False            False
#
#        poutcome_failure  poutcome_nonexistent  poutcome_success   y_no
# 0                 False                  True             False   True
# 1                 False                  True             False   True
# 2                 False                  True             False   True
# 3                 False                  True             False   True
# 4                 False                  True             False   True
# ...                 ...                   ...               ...    ...
# 41183             False                  True             False  False
# 41184             False                  True             False   True
# 41185             False                  True             False   True
# 41186             False                  True             False  False
# 41187              True                 False             False   True
#
# [41188 rows x 64 columns]

# %%
y=df["y_no"]
y
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 41183    False
# 41184     True
# 41185     True
# 41186    False
# 41187     True
# Name: y_no, Length: 41188, dtype: bool

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# C:\Users\Vivek\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy of the model:",accuracy_score(y_pred,y_test))
# Out:
# Accuracy of the model: 0.9167273610099539

# %%
xgb_classifier=xgb.XGBClassifier()
xgb_classifier.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
predictions=xgb_classifier.predict(x_test)

# %%
print("accuracy:",accuracy_score(y_test,predictions))
# Out:
# accuracy: 1.0
