# %% [markdown]
# ## using breast cancer data findout  which classification model is best accuracy score

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np

# %%
list_of_accuracies = []

# %%
breast_cancer = load_breast_cancer()

# %%
breast_cancer.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
breast_cancer.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
df = pd.DataFrame(breast_cancer.data)
df
# Out:
#         0      1       2       3   ...      26      27      28       29
# 0    17.99  10.38  122.80  1001.0  ...  0.7119  0.2654  0.4601  0.11890
# 1    20.57  17.77  132.90  1326.0  ...  0.2416  0.1860  0.2750  0.08902
# 2    19.69  21.25  130.00  1203.0  ...  0.4504  0.2430  0.3613  0.08758
# 3    11.42  20.38   77.58   386.1  ...  0.6869  0.2575  0.6638  0.17300
# 4    20.29  14.34  135.10  1297.0  ...  0.4000  0.1625  0.2364  0.07678
# ..     ...    ...     ...     ...  ...     ...     ...     ...      ...
# 564  21.56  22.39  142.00  1479.0  ...  0.4107  0.2216  0.2060  0.07115
# 565  20.13  28.25  131.20  1261.0  ...  0.3215  0.1628  0.2572  0.06637
# 566  16.60  28.08  108.30   858.1  ...  0.3403  0.1418  0.2218  0.07820
# 567  20.60  29.33  140.10  1265.0  ...  0.9387  0.2650  0.4087  0.12400
# 568   7.76  24.54   47.92   181.0  ...  0.0000  0.0000  0.2871  0.07039
#
# [569 rows x 30 columns]

# %%
df.columns = breast_cancer.feature_names

df.head()
# Out:
#    mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Train The Model

# %%
## Now import the train test model and train the model

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(breast_cancer.data,breast_cancer.target,stratify=breast_cancer.target,
                                                  random_state=42,train_size=0.7)

# %% [markdown]
# ## Import Linear Regression and r2 Scroe

# %%
# Check with the liner regression as this target is multiple then this is a multi-class classification problem

from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
y_pred = linear.predict(x_test)  # Predictions
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.6082384982327755

# %%
list_of_accuracies.append(r2)

# %% [markdown]
# ## Import Logistic Regression and r2 score

# %%
# check with the Logistic Regression
from sklearn.linear_model import LogisticRegression
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)
# Out:
# C:\Users\Vivek\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred = logistic_regression.predict(x_test)  # Predictions
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9415204678362573

# %%
list_of_accuracies.append(accuracy)

# %% [markdown]
# ## Import KNN classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_Model = KNeighborsClassifier(n_neighbors=5, metric= 'minkowski', p = 2)
KNN_Model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = KNN_Model.predict(x_test)
r2_knn_score = r2_score(y_test,y_pred_knn)
r2_knn_score
# Out:
# 0.6753796728971962

# %%
list_of_accuracies.append(r2_knn_score)

# %% [markdown]
# ## Import SVC Model

# %%
from sklearn.svm import SVC
svc_model = SVC(kernel='linear')
svc_model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_svc= svc_model.predict(x_test)
r2_score_svc = r2_score(y_test,y_pred_svc)
r2_score_svc
# Out:
# 0.8002336448598131

# %%
list_of_accuracies.append(r2_score_svc)

# %% [markdown]
# ## Import decissionTree classification

# %%
from sklearn.tree import DecisionTreeClassifier
decission_tree_model = DecisionTreeClassifier(max_depth=2,random_state=0)
decission_tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
y_decision_tree_pred = decission_tree_model.predict(x_test)
r2_decision_tree_score = r2_score(y_test,y_decision_tree_pred)
r2_decision_tree_score
# Out:
# 0.6504088785046729

# %%
list_of_accuracies.append(r2_decision_tree_score)

# %% [markdown]
# ## Import randomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(n_estimators=50, random_state=42)
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=42)

# %%
y_pred_RFC = RFC.predict(x_test)
r2_RFC_score = r2_score(y_test,y_pred_RFC)
r2_RFC_score
# Out:
# 0.6753796728971962

# %%
list_of_accuracies.append(r2_RFC_score)

# %% [markdown]
# ## Import Gussian NB

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_gnb = gnb.predict(x_test)
r2_gnb_score = r2_score(y_test, y_pred_gnb)
r2_gnb_score
# Out:
# 0.7752628504672897

# %%
list_of_accuracies.append(r2_gnb_score)

# %% [markdown]
# ## check all the accuracies

# %%
list_of_accuracies
# Out:
# [0.6082384982327755,
#  0.9415204678362573,
#  0.6753796728971962,
#  0.8002336448598131,
#  0.6504088785046729,
#  0.6753796728971962,
#  0.7752628504672897]
