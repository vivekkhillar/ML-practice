# %%
from sklearn.feature_extraction.text import TfidfVectorizer 

para = ["The itsy bitsy spider crawled up the water spout. Down came the rain, and washed the spider out.Out came the sun, and dried up all the rain,and the itsy bitsy spider went up the spout again."]

vectorizer = TfidfVectorizer()
transform_vector = vectorizer.fit_transform(para)
print(vectorizer.get_feature_names_out())
print(transform_vector)
# Out:
# ['again' 'all' 'and' 'bitsy' 'came' 'crawled' 'down' 'dried' 'itsy' 'out'
#  'rain' 'spider' 'spout' 'sun' 'the' 'up' 'washed' 'water' 'went']
#   (0, 14)	0.7184212081070996
#   (0, 8)	0.1796053020267749
#   (0, 3)	0.1796053020267749
#   (0, 11)	0.26940795304016235
#   (0, 5)	0.08980265101338746
#   (0, 15)	0.26940795304016235
#   (0, 17)	0.08980265101338746
#   (0, 12)	0.1796053020267749
#   (0, 6)	0.08980265101338746
#   (0, 4)	0.1796053020267749
#   (0, 10)	0.1796053020267749
#   (0, 2)	0.26940795304016235
#   (0, 16)	0.08980265101338746
#   (0, 9)	0.1796053020267749
#   (0, 13)	0.08980265101338746
#   (0, 7)	0.08980265101338746
#   (0, 1)	0.08980265101338746
#   (0, 18)	0.08980265101338746
#   (0, 0)	0.08980265101338746

# %%
from sklearn.feature_extraction.text import CountVectorizer 

para = ["The itsy bitsy spider crawled up the water spout. Down came the rain, and washed the spider out. Out came the sun, and dried up all the rain,and the itsy bitsy spider went up the spout again."]

vectorizer = CountVectorizer()
transform_vector = vectorizer.fit_transform(para)
print(vectorizer.get_feature_names_out())
print(transform_vector)
# Out:
# ['again' 'all' 'and' 'bitsy' 'came' 'crawled' 'down' 'dried' 'itsy' 'out'
#  'rain' 'spider' 'spout' 'sun' 'the' 'up' 'washed' 'water' 'went']
#   (0, 14)	8
#   (0, 8)	2
#   (0, 3)	2
#   (0, 11)	3
#   (0, 5)	1
#   (0, 15)	3
#   (0, 17)	1
#   (0, 12)	2
#   (0, 6)	1
#   (0, 4)	2
#   (0, 10)	2
#   (0, 2)	3
#   (0, 16)	1
#   (0, 9)	2
#   (0, 13)	1
#   (0, 7)	1
#   (0, 1)	1
#   (0, 18)	1
#   (0, 0)	1

# %%
para = ["The itsy bitsy spider crawled up the water spout. Down came the rain, and washed the spider out. Out came the sun, and dried up all the rain,and the itsy bitsy spider went up the spout again."]
mapping={}
for i in (para[0]).split():
    if i not in mapping:
        mapping[i] =1
    else:
        mapping[i]+=1

print(mapping)
# Out:
# {'The': 1, 'itsy': 2, 'bitsy': 2, 'spider': 3, 'crawled': 1, 'up': 3, 'the': 7, 'water': 1, 'spout.': 1, 'Down': 1, 'came': 2, 'rain,': 1, 'and': 2, 'washed': 1, 'out.': 1, 'Out': 1, 'sun,': 1, 'dried': 1, 'all': 1, 'rain,and': 1, 'went': 1, 'spout': 1, 'again.': 1}

# %%
mapping ={}

for i in " ".join(para).split():
    
    mapping[i] = 1 if i not in mapping else mapping[i] +1

print (mapping)
# Out:
# {'The': 1, 'itsy': 2, 'bitsy': 2, 'spider': 3, 'crawled': 1, 'up': 3, 'the': 7, 'water': 1, 'spout.': 1, 'Down': 1, 'came': 2, 'rain,': 1, 'and': 2, 'washed': 1, 'out.': 1, 'Out': 1, 'sun,': 1, 'dried': 1, 'all': 1, 'rain,and': 1, 'went': 1, 'spout': 1, 'again.': 1}

# %%
para = ["The itsy bitsy spider crawled up the water spout. Down came the rain, and washed the spider out. Out came the sun, and dried up all the rain,and the itsy bitsy spider went up the spout again."]

# %%
mapping = {}
for i in para[0].split():
    if i not in mapping:
        mapping[i] = 1
    else:
        mapping[i] += 1
mapping
# Out:
# {'The': 1,
#  'itsy': 2,
#  'bitsy': 2,
#  'spider': 3,
#  'crawled': 1,
#  'up': 3,
#  'the': 7,
#  'water': 1,
#  'spout.': 1,
#  'Down': 1,
#  'came': 2,
#  'rain,': 1,
#  'and': 2,
#  'washed': 1,
#  'out.': 1,
#  'Out': 1,
#  'sun,': 1,
#  'dried': 1,
#  'all': 1,
#  'rain,and': 1,
#  'went': 1,
#  'spout': 1,
#  'again.': 1}

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
cv = CountVectorizer(stop_words= "english")
vectors = cv.fit_transform(para)
print (cv.get_feature_names_out())
# Out:
# ['bitsy' 'came' 'crawled' 'dried' 'itsy' 'rain' 'spider' 'spout' 'sun'
#  'washed' 'water' 'went']
