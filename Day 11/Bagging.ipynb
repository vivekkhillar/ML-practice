# %% [markdown]
# ## Baggin Classifier

# %%
# import libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier

# %%
# Import dataset from Github opensource
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
names  = ['preg','plas','pres','skin','test','mass','pedi','age','class']

# %%
Dataframe = pd.read_csv(url, names=names)
Dataframe
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
Dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   preg    768 non-null    int64
#  1   plas    768 non-null    int64
#  2   pres    768 non-null    int64
#  3   skin    768 non-null    int64
#  4   test    768 non-null    int64
#  5   mass    768 non-null    float64
#  6   pedi    768 non-null    float64
#  7   age     768 non-null    int64
#  8   class   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
Dataframe.isnull().sum()
# Out:
# preg     0
# plas     0
# pres     0
# skin     0
# test     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %%
array = Dataframe.values
array
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
# Import decission tree classifier
x = array[:,0:8] # independent variables
y = array[:,8] # dependent variable / target variable

# %%
seed=7
kfold = model_selection.KFold(n_splits=10, random_state=seed, shuffle=True)
cart = DecisionTreeClassifier()
num_trees = 100

# %%
model=BaggingClassifier(estimator=cart,n_estimators=num_trees,random_state=seed)

# %%
results = model_selection.cross_val_score(model,x,y, cv=kfold)
results
# Out:
# array([0.76623377, 0.75324675, 0.74025974, 0.77922078, 0.80519481,
#        0.79220779, 0.66233766, 0.75324675, 0.78947368, 0.73684211])

# %%
print(results.mean())
# Out:
# 0.7578263841421736

# %%
import pandas
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

url='https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
names=['preg','plas','pres','skin','test','mass','pedi','age','class']
dataframe= pandas.read_csv(url,names=names)

# %%
dataframe
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
x1=array[:,0:8]
y1=array[:,8]

# %%
## Import Random Forest Classifier
seed=7 
num_trees=100
max_features=3
kFold = model_selection.KFold(n_splits=10, random_state=seed, shuffle=True)
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)
results1 = model_selection.cross_val_score(model,x1,y1, cv= kFold)
results1
# Out:
# array([0.81818182, 0.76623377, 0.7012987 , 0.79220779, 0.80519481,
#        0.80519481, 0.68831169, 0.79220779, 0.81578947, 0.75      ])

# %%
print(results1.mean())
# Out:
# 0.773462064251538

# %%
import pandas
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

url='https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
names=['preg','plas','pres','skin','test','mass','pedi','age','class']
dataframe= pandas.read_csv(url,names=names)

# %%
dataframe
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
x2=array[:,0:8]
y2=array[:,8]

# %%
## Import extra trees classifier
seed=7 
num_trees=100
max_features=3
model = ExtraTreesClassifier(n_estimators=num_trees, max_features=max_features)
results2 = model_selection.cross_val_score(model,x2,y2, cv= kFold)
results2
# Out:
# array([0.79220779, 0.79220779, 0.68831169, 0.77922078, 0.75324675,
#        0.79220779, 0.68831169, 0.83116883, 0.82894737, 0.76315789])

# %%
print(results2.mean())
# Out:
# 0.7708988380041013
